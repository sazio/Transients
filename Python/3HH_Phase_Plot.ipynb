# %% [markdown]
# <a href="https://colab.research.google.com/github/sazio/Transients/blob/master/Python/3HH_Phase_Plot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt 
import numpy as np
import pandas as pd
import plotly.express as px

import warnings
warnings.filterwarnings('ignore')

# %%
# Import data from GDrive
from google.colab import drive
drive.mount('/content/drive', force_remount= True)
# Out:
# Mounted at /content/drive

# %%
path = "drive/MyDrive/Tesi/"

# %%
neuron1 = np.fromfile(path + "Neuron1HH.csv")
neuron2 = np.fromfile(path + "Neuron2HH.csv")
neuron3 = np.fromfile(path + "Neuron3HH.csv")
neuron2 = neuron2[:neuron1.shape[0]]
neuron3 = neuron3[:neuron1.shape[0]]

#neurons_df = pd.DataFrame(data = [neuron1,neuron2,neuron3], columns = ["HH1", "HH2", "HH3"])

# %%
print(neuron1.shape)
print(neuron2.shape)
print(neuron3.shape)
# Out:
# (1182368,)
# (1182368,)
# (1182368,)

# %%
px.line_3d(x = neuron1[:3000], y = neuron2[:3000], z = neuron3[:3000])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="07f89368-4706-4b8b-adff-73bf40bdc142" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("07f89368-4706-4b8b-adff-73bf40bdc142")) {
#                     Plotly.newPlot(
#                         '07f89368-4706-4b8b-adff-73bf40bdc142',
# ...

# %%
neuron1.max()
# Out:
# 4.857875059723576e-33
